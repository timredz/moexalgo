# %%
from moexalgo import Market, Ticker

# %%
eq = Market('EQ')
eq.tickers()
# Out:
#      SECID BOARDID   SHORTNAME  PREVPRICE  LOTSIZE  FACEVALUE STATUS  \
# 0     ABRD    TQBR  АбрауДюрсо    355.800       10       1.00      A
# 1     ACKO    TQBR     АСКО ао      3.580      100       1.00      N
# 2     AFKS    TQBR  Система ао     18.647      100       0.09      A
# 3     AFLT    TQBR    Аэрофлот     45.260       10       1.00      A
# 4     AGRO    TQBR    AGRO-гдр   1170.000        1       0.00      A
# ..     ...     ...         ...        ...      ...        ...    ...
# 243   YNDX    TQBR  Yandex clA   2709.400        1       0.01      A
# 244   YRSB    TQBR     ТНСэнЯр   1014.000       10       1.00      A
# 245  YRSBP    TQBR   ТНСэнЯр-п    250.000       10       1.00      A
# 246   ZILL    TQBR      ЗИЛ ао   3600.000        1    1000.00      A
# 247   ZVEZ    TQBR   ЗВЕЗДА ао      7.500     1000       0.10      A
#
#                       BOARDNAME  DECIMALS                        SECNAME  ...  \
# ...

# %%
eq.stats()
# Out:
#      SECID BOARDID       BID  BIDDEPTH     OFFER  OFFERDEPTH  SPREAD  \
# 0     ABRD    TQBR   367.200        63   367.400           8   0.200
# 1     ACKO    TQBR       NaN         0       NaN           0   0.000
# 2     AFKS    TQBR    18.779         3    18.786           5   0.007
# 3     AFLT    TQBR    45.700      1876    45.720           1   0.020
# 4     AGRO    TQBR  1153.600         6  1153.800          80   0.200
# ..     ...     ...       ...       ...       ...         ...     ...
# 243   YNDX    TQBR  2762.400        30  2763.200         100   0.800
# 244   YRSB    TQBR  1400.000         1  1412.000           3  12.000
# 245  YRSBP    TQBR   337.000         1   337.500           4   0.500
# 246   ZILL    TQBR  3585.000         9  3600.000           6  15.000
# 247   ZVEZ    TQBR     7.520         5     7.570           7   0.050
#
#      BIDDEPTHT  OFFERDEPTHT      OPEN  ...  OPENPERIODPRICE          SEQNUM  \
# ...

# %%
moex = Ticker('MOEX/TQBR')
moex.info()
# Out:
#                                                         title           value
# SHORTNAME                  Краткое наименование ценной бумаги        МосБиржа
# LOTSIZE      Количество ценных бумаг в одном стандартном лоте              10
# STATUS      Индикатор "торговые операции разрешены/запрещены"               A
# DECIMALS                       Точность, знаков после запятой               2
# MINSTEP     Минимально возможная разница между ценами, ука...            0.01
# ISSUESIZE                                       Объем выпуска      2276401458
# ISIN        Международный идентификационный код ценной бумаги    RU000A0JR4A1
# LATNAME     Наименование финансового инструмента на англий...  MoscowExchange
# CURRENCYID                                    Валюта расчетов             SUR
# SECTYPE                                     Тип ценной бумаги               1
# LISTLEVEL                                    Уровень листинга               1

# %%
moex.orderbook()
# Out:
#    BOARDID SECID BUYSELL   PRICE  QUANTITY          SEQNUM UPDATETIME  \
# 0     TQBR  MOEX       S  133.79        53  20230803162459   16:24:58
# 1     TQBR  MOEX       S  133.77         4  20230803162459   16:24:58
# 2     TQBR  MOEX       S  133.76        58  20230803162459   16:24:58
# 3     TQBR  MOEX       S  133.75        32  20230803162459   16:24:58
# 4     TQBR  MOEX       S  133.72       500  20230803162459   16:24:58
# 5     TQBR  MOEX       S  133.70       421  20230803162459   16:24:58
# 6     TQBR  MOEX       S  133.66         3  20230803162459   16:24:58
# 7     TQBR  MOEX       S  133.64       124  20230803162459   16:24:58
# 8     TQBR  MOEX       S  133.63      4187  20230803162459   16:24:58
# 9     TQBR  MOEX       S  133.62       210  20230803162459   16:24:58
# 10    TQBR  MOEX       B  133.61       209  20230803162459   16:24:58
# 11    TQBR  MOEX       B  133.60      7643  20230803162459   16:24:58
# ...

# %%
moex.candles('2023-01-01', limit=1000)
# Out:
#        open   close    high     low        value    volume  \
# 0     95.40   95.40   95.40   95.40     240408.0    2520.0
# 1     95.40   95.42   96.15   94.90   59790027.4  627080.0
# 2     95.42   95.65   95.90   95.40   13410778.3  140170.0
# 3     95.62   95.47   95.65   95.43    5233924.4   54810.0
# 4     95.45   95.30   95.48   95.25    7772928.6   81510.0
# ..      ...     ...     ...     ...          ...       ...
# 995  111.54  111.49  111.70  111.17  101552581.4  911390.0
# 996  111.49  111.34  111.55  111.30   21130252.9  189680.0
# 997  111.34  111.42  111.53  111.33   35431894.8  318030.0
# 998  111.50  111.60  111.70  111.44   35873514.3  321370.0
# 999  111.61  111.71  111.71  111.50   16530192.2  148080.0
#
#                   begin                 end
# 0   2023-01-03 09:00:00 2023-01-03 09:59:59
# 1   2023-01-03 10:00:00 2023-01-03 10:59:59
# 2   2023-01-03 11:00:00 2023-01-03 11:59:59
# 3   2023-01-03 12:00:00 2023-01-03 12:59:59
# ...

# %%
imoex = Ticker('IMOEX')
imoex.info()
# Out:
#                                            title            value
# SECID                                Код индекса            IMOEX
# BOARDID                                    Режим             SNDX
# NAME                                Наименование  Индекс МосБиржи
# DECIMALS          Точность, знаков после запятой                2
# SHORTNAME                   Наименование индекса  Индекс МосБиржи
# ANNUALHIGH  Максимальное значение индекса за год          3123.45
# ANNUALLOW    Минимальное значение индекса за год          1775.04
# CURRENCYID                        Валюта расчета              RUB
# CALCMODE                         Принцип расчета             None

# %%
imoex.candles('2020-01-01', interval=1, limit=500)
# Out:
#         open    close     high      low         value  volume  \
# 0    3059.20  3062.08  3063.66  3057.36  5.614901e+08     0.0
# 1    3062.07  3064.59  3065.64  3061.65  3.335770e+08     0.0
# 2    3065.17  3068.52  3068.52  3065.13  2.777729e+08     0.0
# 3    3068.75  3069.34  3070.16  3067.80  1.851880e+08     0.0
# 4    3069.88  3071.54  3071.54  3069.80  1.785591e+08     0.0
# ..       ...      ...      ...      ...           ...     ...
# 495  3073.83  3074.45  3074.60  3073.78  1.110228e+08     0.0
# 496  3074.45  3074.52  3074.68  3074.40  7.817579e+07     0.0
# 497  3074.47  3075.02  3075.02  3074.41  1.195468e+08     0.0
# 498  3075.02  3075.22  3075.35  3074.95  9.306601e+07     0.0
# 499  3075.22  3074.57  3075.29  3074.54  9.513415e+07     0.0
#
#                   begin                 end
# 0   2020-01-03 10:00:00 2020-01-03 10:00:59
# 1   2020-01-03 10:01:00 2020-01-03 10:01:59
# 2   2020-01-03 10:02:00 2020-01-03 10:02:59
# ...
